# %%
import numpy as np

# %load_ext line_profiler

# %%
def convert_units(heroes, heights, weights):

    new_hts = [ht * 0.39370  for ht in heights]
    new_wts = [wt * 2.20462  for wt in weights]

    hero_data = {}

    for i,hero in enumerate(heroes):
        hero_data[hero] = (new_hts[i], new_wts[i])

    return hero_data

# %%
heroes = ['Batman', 'Superman', 'Wonder Woman'] 
hts = np.array([188.0, 191.0, 183.0]) 
wts = np.array([ 95.0, 101.0,  74.0])

# %%
# %timeit convert_units(heroes, hts, wts)
# Out:
# 2.14 µs ± 99.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %lprun -f convert_units convert_units(heroes, hts, wts)
# Out:
# Timer unit: 1e-09 s
#
# Total time: 2.0993e-05 s
# File: /tmp/ipykernel_46927/1811563529.py
# Function: convert_units at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def convert_units(heroes, heights, weights):
#      2
#      3         1      12748.0  12748.0     60.7      new_hts = [ht * 0.39370  for ht in heights]
#      4         1       2883.0   2883.0     13.7      new_wts = [wt * 2.20462  for wt in weights]
#      5
#      6         1        431.0    431.0      2.1      hero_data = {}
#      7
#      8         4       3015.0    753.8     14.4      for i,hero in enumerate(heroes):
#      9         3       1777.0    592.3      8.5          hero_data[hero] = (new_hts[i], new_wts[i])
#     10
#     11         1        139.0    139.0      0.7      return hero_data
