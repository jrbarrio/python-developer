# %%
# Create a list using the formal name
# %timeit formal_list = list()
# Out:
# 36.8 ns ± 0.161 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# Create a list using the literal syntax
# %timeit literal_list = []
# Out:
# 13.8 ns ± 0.277 ns per loop (mean ± std. dev. of 7 runs, 100,000,000 loops each)
