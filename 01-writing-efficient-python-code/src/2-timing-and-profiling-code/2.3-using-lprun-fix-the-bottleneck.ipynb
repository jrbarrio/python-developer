# %%
import numpy as np

# %load_ext line_profiler
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
def convert_units_broadcast(heroes, heights, weights):

    # Array broadcasting instead of list comprehension
    new_hts = heights * 0.39370
    new_wts = weights * 2.20462

    hero_data = {}

    for i,hero in enumerate(heroes):
        hero_data[hero] = (new_hts[i], new_wts[i])

    return hero_data

# %%
heroes = ['Batman', 'Superman', 'Wonder Woman'] 
hts = np.array([188.0, 191.0, 183.0]) 
wts = np.array([ 95.0, 101.0,  74.0])

# %%
# %timeit convert_units_broadcast(heroes, hts, wts)
# Out:
# 1.75 µs ± 24.5 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %lprun -f convert_units_broadcast convert_units_broadcast(heroes, hts, wts)
# Out:
# Timer unit: 1e-09 s
#
# Total time: 2.5615e-05 s
# File: /tmp/ipykernel_51130/2887860108.py
# Function: convert_units_broadcast at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def convert_units_broadcast(heroes, heights, weights):
#      2
#      3                                               # Array broadcasting instead of list comprehension
#      4         1      18255.0  18255.0     71.3      new_hts = heights * 0.39370
#      5         1       1276.0   1276.0      5.0      new_wts = weights * 2.20462
#      6
#      7         1        310.0    310.0      1.2      hero_data = {}
#      8
#      9         4       2017.0    504.2      7.9      for i,hero in enumerate(heroes):
#     10         3       3556.0   1185.3     13.9          hero_data[hero] = (new_hts[i], new_wts[i])
#     11
#     12         1        201.0    201.0      0.8      return hero_data
